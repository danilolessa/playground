# %%
import requests; import json;

# %%
payload={};
payload["Cookie"]="JSESSIONID=oqBHf6hxCes-bcNdwR3ZTQ"
payload["Accept-Encoding"]="gzip, deflate,sdch";
payload["Referer"]="http://bustime.noxxonsat.com.br/emtu/v4/emtu.html?linha=035";
init_url="http://bustime.noxxonsat.com.br/emtu/v4/emtu.html?linha=035";
url="http://bustime.noxxonsat.com.br/bustime?linha=035";
r=requests.get(url, headers=payload)

# %%
dat=r.json()

# %%
dat["linhas"]
# Out:
# [{'ts': 'Sao Paulo (Metro Butanta)',
#   'rotas': [{'sentido': 'ida',
# ...

# %%
# Out:
# b''
